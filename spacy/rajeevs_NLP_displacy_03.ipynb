# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp(u"Carter robot is developed using Isaac SDK software by NVIDIA. BMW has also bought this software for their STR robot at $2.3 million per year!")
displacy.render(doc, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5518b74ff6d9410398e8099906477be0-0" class="displacy" width="2910" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Carter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">robot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">developed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">Isaac</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">SDK</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">software</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">NVIDIA.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">BMW</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">bought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">software</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">STR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">robot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">2.3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">per</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">year!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5518b74ff6d9410398e8099906477be0-0-0" stroke-width="2px" d="M70,277.0 C70,222.0 140.0,222.0 140.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5518b74ff6d9410398e8099906477be0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,279.0 L62,267.0 78,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5518b74ff6d9410398e8099906477be0-0-1" stroke-width="2px" d="M180,277.0 C180,167.0 365.0,167.0 365.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5518b74ff6d9410398e8099906477be0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,279.0 L172,267.0 188,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="a

# %%
displacy.render(doc, style='ent', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  robot is developed using
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isaac SDK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  software by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NVIDIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BMW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has also bought this software for their STR robot at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $2.3 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  per year!</div></span>
